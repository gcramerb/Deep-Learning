# %% [markdown]
# # Aprendizado Profundo - UFMG
#
# ## Preâmbulo
#
# O código abaixo consiste dos imports comuns. Além do mais, configuramos as imagens para ficar de um tamanho aceitável e criamos algumas funções auxiliares. No geral, você pode ignorar a próxima célula.

# %%
# !pip install mxnet-cu100==1.4.1
# Out:
# Collecting mxnet-cu100==1.4.1
#   Downloading https://files.pythonhosted.org/packages/19/91/b5c2692297aa5b8c383e0da18f9208fc6d5519d981c03266abfbde897c41/mxnet_cu100-1.4.1-py2.py3-none-manylinux1_x86_64.whl (488.3MB)
#      |████████████████████████████████| 488.3MB 32kB/s
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.6/dist-packages (from mxnet-cu100==1.4.1) (2.21.0)
# Collecting numpy<1.15.0,>=1.8.2 (from mxnet-cu100==1.4.1)
#   Downloading https://files.pythonhosted.org/packages/e5/c4/395ebb218053ba44d64935b3729bc88241ec279915e72100c5979db10945/numpy-1.14.6-cp36-cp36m-manylinux1_x86_64.whl (13.8MB)
#      |████████████████████████████████| 13.8MB 34.9MB/s
# Collecting graphviz<0.9.0,>=0.8.1 (from mxnet-cu100==1.4.1)
#   Downloading https://files.pythonhosted.org/packages/53/39/4ab213673844e0c004bed8a0781a0721a3f6bb23eb8854ee75c236428892/graphviz-0.8.4-py2.py3-none-any.whl
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20.0->mxnet-cu100==1.4.1) (2019.6.16)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20.0->mxnet-cu100==1.4.1) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20.0->mxnet-cu100==1.4.1) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20.0->mxnet-cu100==1.4.1) (1.24.3)
# ERROR: spacy 2.1.8 has requirement numpy>=1.15.0, but you'll have numpy 1.14.6 which is incompatible.
# ERROR: imgaug 0.2.9 has requirement numpy>=1.15.0, but you'll have numpy 1.14.6 which is incompatible.
# ERROR: fastai 1.0.57 has requirement numpy>=1.15, but you'll have numpy 1.14.6 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: cvxpy 1.0.24 has requirement numpy>=1.15, but you'll have numpy 1.14.6 which is incompatible.
# ERROR: blis 0.2.4 has requirement numpy>=1.15.0, but you'll have numpy 1.14.6 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: numpy, graphviz, mxnet-cu100
#   Found existing installation: numpy 1.16.4
#     Uninstalling numpy-1.16.4:
#       Successfully uninstalled numpy-1.16.4
#   Found existing installation: graphviz 0.10.1
#     Uninstalling graphviz-0.10.1:
#       Successfully uninstalled graphviz-0.10.1
# Successfully installed graphviz-0.8.4 mxnet-cu100-1.4.1 numpy-1.14.6

# %%
# -*- coding: utf8

import matplotlib.pyplot as plt

import mxnet as mx
from mxnet import autograd
import mxnet.ndarray as nd

import numpy as np

plt.rcParams['figure.figsize']  = (18, 10)
plt.rcParams['axes.labelsize']  = 20
plt.rcParams['axes.titlesize']  = 20
plt.rcParams['legend.fontsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 20
plt.rcParams['lines.linewidth'] = 4

# %%
plt.ion()

plt.style.use('seaborn-colorblind')
plt.rcParams['figure.figsize']  = (12, 8)

# %% [markdown]
# Para testar o resultado dos seus algoritmos vamos usar o módulo testing do numpy.

# %%
from numpy.testing import assert_equal
from numpy.testing import assert_almost_equal
from numpy.testing import assert_array_almost_equal
import math

# %% [markdown]
# ## Aula 02 - Regressão Linear e Logística from Scratch
#
# Um fator importante de salientar é que embora nosso curso está fazendo uso de mxnet nas aulas iniciais, vamos migrar para outros frameworks estilo PyTorch ao longo das aulas. No fim, todos são bem parecidos e aplicam as mesmas ideias de diferenciação automática. Para brincar um pouco mais com essa diferenciação, nesta aula vamos implementar a regressão linear e logística do zero. Vamos fazer duas versões de cada:
#
# 1. Derivando na mão, não é complicado.
# 2. Derivando com mxnet

# %% [markdown]
# ## Conjunto de Problemas 1: Mais Derivadas

# %% [markdown]
# Antes de entrar na regressão, vamos brincar um pouco de derivadas dentro de funções. Dado dois números `x` and `y`, implemente a função `log_exp` que retorna:
#
# $$-\log\left(\frac{e^x}{e^x+e^y}\right)$$

# %%
def log_exp(x, y):
    # implemente
    num = np.exp(x)
    dem = num + np.exp(y)
    result = -1*np.log(num/dem)
    return result
    pass

# %% [markdown]
# 1. Abaixo vamos testar o seu código com algumas entradas simples.

# %%
x, y = nd.array([2]), nd.array([3])
z = log_exp(x, y)
z
# Out:
# array([[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [1.3132617]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]], dtype=object)

# %%
# Teste. Não apague
assert_equal(1.31326175, z)

# %% [markdown]
# 2. Agora implementa uma função para computar $\partial z/\partial x$ e $\partial z/\partial y$ usando `autograd`.

# %%
# O argumento funcao_forward é uma função python. Será a sua log_exp.
# A ideia aqui é deixar claro a ideia de forward e backward propagation, depois
# de avaliar a função chamamos backward e temos as derivadas.

def grad(funcao_forward, x, y):
    x.attach_grad()
    y.attach_grad()
    with mx.autograd.record():
        z = funcao_forward(x, y)
    z.backward()
    return x.grad, y.grad

# %% [markdown]
# Testando

# %%
x, y = nd.array([2]), nd.array([3])
dx, dy = grad(log_exp, x, y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-0b0ee6ffe111> in <module>()
#       1 x, y = nd.array([2]), nd.array([3])
# ----> 2 dx, dy = grad(log_exp, x, y)
#
# <ipython-input-54-c3b5f60568b6> in grad(funcao_forward, x, y)
#       5     with mx.autograd.record():
#       6         z = funcao_forward(x, y)
# ----> 7     z.backward()
#       8     return x.grad, y.grad
#
# AttributeError: 'numpy.ndarray' object has no attribute 'backward'

# %%
assert_equal(-0.7310586, dx.asnumpy())
assert_equal(0.7310586, dy.asnumpy())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-616c3a845dc6> in <module>()
# ----> 1 assert_equal(-0.7310586, dx.asnumpy())
#       2 assert_equal(0.7310586, dy.asnumpy())
#
# NameError: name 'dx' is not defined

# %% [markdown]
# 4. Agora teste com números maiores, algum problema?

# %%
x, y = nd.array([50]), nd.array([100])
grad(log_exp, x, y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-a384ef8fd3cd> in <module>()
#       1 x, y = nd.array([50]), nd.array([100])
# ----> 2 grad(log_exp, x, y)
#
# <ipython-input-54-c3b5f60568b6> in grad(funcao_forward, x, y)
#       5     with mx.autograd.record():
#       6         z = funcao_forward(x, y)
# ----> 7     z.backward()
#       8     return x.grad, y.grad
#
# AttributeError: 'numpy.ndarray' object has no attribute 'backward'

# %% [markdown]
# 5. Pense um pouco sobre o motivo do erro acima. Usando as propriedade de logaritmos, é possível fazer uma função mais estável? Implemente a mesma abaixo. O problema aqui é que o exponencial "explode" quando x ou y são muito grandes. Use o [link](http://www.wolframalpha.com/input/?i=log[e%5Ex+%2F+[e%5Ex+%2B+e%5Ey]]) para lhe ajudar.

# %%
def stable_log_exp(x, y):
  
  # vamos implementar a forma alternativa do wolfram alfa:
  # e usar a propriedade do logaritmo para evitar colocar as variáveis no denominador.
  
  # o -1 é cortado com o -1 que surge
  
  return nd.log(nd.exp(y-x) + 1)


dx, dy = grad(stable_log_exp, x, y)

# %%
stable_log_exp(x, y)
# Out:
# [50.]
# <NDArray 1 @cpu(0)>

# %%
# Teste. Não apague
assert_equal(-1, dx.asnumpy())
assert_equal(1, dy.asnumpy())

# %% [markdown]
# O exemplo acima mostra um pouco de problemas de estabilidade númerica. às vezes é melhor usar versões alternativas de funções. Isto vai ocorrer quando você ver vários nans na sua frente :-) Claro, estamos assumindo que existe uma outra função equivalente que é mais estável para o computador.

# %% [markdown]
# ## Conjunto de Problemas 2: Regressão Linear
#
# Agora, vamos explorar uma regressão linear. Embora não vamos fazer uso da logexp acima, a ideia de derivar parcialmente dentro de funções pode nos ajudar. Lembrando da regressão linear, inicialmente temos um conjunto observações representadas como tuplas $(\mathbf{x}_i, y_i)$. Aqui, $\mathbf{x}_i$ é um vetor de atributos. Vamo forçar $\mathbf{x}_{i0} = 1$, capturando assim o intercepto. Além do mais, $\mathbf{x}_{ij}$ quando $j\neq 0$, são os outros atributos de entrada. $y_i$ uma valor real representando uma resposta. Nossa regressão visa capturar:
#
# $$y_i = 1 + \theta_1 x_{i1} + \theta_2 x_{i2} + \cdots + \theta_k x_{if}$$
#
# Lembrando da regressão linear multivariada, podemos representar as equações como uma multiplicação de uma matriz com um vetor
#
# ![](./figs/linear.png)
#
# 7. Crie uma função de previsao. A mesma recebe uma matrix $\mathbf{X}$ e um vetor de parâmetros $\theta$. Sua função deve retornar um vetor de previsões para cada linha de $\mathbf{X}$. Não use nenhum laço!!

# %%
def previsao(X, theta):
  
  print('---------')
  print(theta.shape)
  print(X.shape)
  print('---------')
  y_hat = np.dot(X,theta)
  return y_hat

# %% [markdown]
# **Erros quadrados**. Para aprender os parâmetros ótimos da regressão linear, precisamos fazer uso de um modelo de erros quadrados. Em particular nosso objetico é aprender os parâmetros que minimizam a função:
#
# $$L(\mathbf{\theta}) = n^{-1} \sum_i ({\hat{y}_i - y_i})^2$$
#
# Onde $\hat{y}_i$ é uma previsão (vêm da sua função python acima). $y_i$ é o valor real dos dados.
#
# 8. Implemente uma função para a média dos os erros quadrados.

# %%
def media_erros_quadrados(X, theta, y):
  
  y_hat = previsao(X,theta)
  erro = y_hat - y
  erro = np.power(erro,2)
  return erro.mean()

# %% [markdown]
# 9. Agora, crie **DUAS** funções que derivam o erro acima. A primeira deve usar o autograd de mxnet. Lembre-se que temos um vetor de parâmetros $\theta$. Por sorte, você pode fazer derivadas de tais vetores também.

# %%
def derivada_mxnet(X, theta, y):
    theta.attach_grad()
    with mx.autograd.record():
        e = media_erros_quadrados(X, theta, y)
    e.backward()
    return theta.grad

# %% [markdown]
# 10. A segunda versão não usa mxnet. Implemente as derivadas do zero. Nos [slides](https://docs.google.com/presentation/d/1bz3G3fEohNtvERKSDtThfGPYOjF83Fzy2yHPdCAlFZw/edit#slide=id.g584f66d2ae_3_74) do link explicamos como fazer tal operação.

# %%
x, y = nd.array([2]), nd.array([3])
def derivada_navera(X, theta, y):
    # pelo slide, temos : ((y - X @ 𝛉) * X.T).mean(axis=1)
  
  y_hat = np.dot(X, theta)
  return ((y_hat - y) * X.T).mean(axis=1)

# %%
#x, y = nd.array([2,5,9],[2,3,4]), nd.array([3])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-ba94f31623a6> in <module>()
# ----> 1 x, y = nd.array([2,5,9],[2,3,4]), nd.array([3])
#       2 x
#
# /usr/local/lib/python3.6/dist-packages/mxnet/ndarray/utils.py in array(source_array, ctx, dtype)
#     144         return _sparse_array(source_array, ctx=ctx, dtype=dtype)
#     145     else:
# --> 146         return _array(source_array, ctx=ctx, dtype=dtype)
#     147
#     148
#
# /usr/local/lib/python3.6/dist-packages/mxnet/ndarray/ndarray.py in array(source_array, ctx, dtype)
#    2486             except:
#    2487                 raise TypeError('source_array must be array like object')
# -> 2488     arr = empty(source_array.shape, ctx, dtype)
#    2489     arr[:] = source_array
#    2490     return arr
#
# /usr/local/lib/python3.6/dist-packages/mxnet/ndarray/ndarray.py in empty(shape, ctx, dtype)
#    3875     if dtype is None:
#    3876         dtype = mx_real_t
# -> 3877     return NDArray(handle=_new_alloc_handle(shape, ctx, False, dtype))
#    3878
#    3879
#
# /usr/local/lib/python3.6/dist-packages/mxnet/ndarray/ndarray.py in _new_alloc_handle(shape, ctx, delay_alloc, dtype)
#     134         c_array_buf(mx_uint, native_array('I', shape)),
#     135         mx_uint(len(shape)),
# --> 136         ctypes.c_int(ctx.device_typeid),
#     137         ctypes.c_int(ctx.device_id),
#     138         ctypes.c_int(int(delay_alloc)),
#
# AttributeError: 'list' object has no attribute 'device_typeid'

# %% [markdown]
# 11. Por fim, otimize sua função usando o algoritmo de gradiente descendente abaixo.

# %%
def gd(d_fun, loss_fun, X, y, lambda_=0.01, tol=0.00001, max_iter=10000):
    '''
    Executa Gradiente Descendente. Aqui:
    
    Parâmetros
    ----------
    d_fun : é uma função de derivadas
    loss_fun : é uma função de perda
    X : é um vetor de fatores explanatórios.
        Copie seu código de intercepto da primeira aula.
        para adicionar o intercepto em X.
    y : é a resposta
    lambda : é a taxa de aprendizad
    tol : é a tolerância, define quando o algoritmo vai parar.
    max_ter : é a segunda forma de parada, mesmo sem convergir
              paramos depois de max_iter iterações.
    '''
    theta = nd.random.normal(shape=X.shape[1])
    print('Iter {}; theta = '.format(0), theta)
    old_err_sq = np.inf
    i = 0
    while True:
        # Computar as derivadas
        grad = d_fun(X, theta, y)
        # Atualizar
        theta_novo = theta - lambda_ * grad
        
        # Parar quando o erro convergir
        print( 'theta:')
        print(theta.shape)
        err_sq = loss_fun(X, theta, y)
        if nd.abs(old_err_sq - err_sq) <= tol:
            break
        
        # Atualizar parâmetros e erro
        theta = theta_novo
        old_err_sq = err_sq
        
        # Informação de debug
        print('Iter {}; theta = '.format(i+1), theta)
        i += 1
        if i == max_iter:
            break
    return theta

# %%
# Para testes, não apague!!!
X = nd.zeros(shape=(1000, 2))
X[:, 0] = 1
X[:, 1] = nd.random.normal(shape=1000)

theta_0_real = 7
theta_1_real = 9
y = theta_0_real + theta_1_real * X[:, 1]

# %%
# Sua função deve retornar algo perto de 7 e 9
theta = gd(derivada_mxnet, media_erros_quadrados, X, y)
print(X.shape)
print(y.shape)

# não funciana !!!
# Out:
# Iter 0; theta =
# [0.02482807 0.00955429]
# <NDArray 2 @cpu(0)>
# ---------
# (2,)
# (1000, 2)
# ---------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-5fb278139d2f> in <module>()
# ----> 1 theta = gd(derivada_mxnet, media_erros_quadrados, X, y)
#       2 print(X.shape)
#       3 print(y.shape)
#
# <ipython-input-90-d6c51819d4aa> in gd(d_fun, loss_fun, X, y, lambda_, tol, max_iter)
#      22     while True:
#      23         # Computar as derivadas
# ---> 24         grad = d_fun(X, theta, y)
#      25         # Atualizar
#      26         theta_novo = theta - lambda_ * grad
#
# <ipython-input-69-fea7b8195668> in derivada_mxnet(X, theta, y)
#       2     theta.attach_grad()
#       3     with mx.autograd.record():
# ----> 4         e = media_erros_quadrados(X, theta, y)
#       5     e.backward()
#       6     return theta.grad
#
# <ipython-input-82-ae9b04fb586b> in media_erros_quadrados(X, theta, y)
#       1 def media_erros_quadrados(X, theta, y):
#       2
# ----> 3   y_hat = previsao(X,theta)
#       4   erro = y_hat - y
#       5   erro = np.power(erro,2)
#
# <ipython-input-97-8336f23034f8> in previsao(X, theta)
#       5   print(X.shape)
#       6   print('---------')
# ----> 7   y_hat = np.dot(X,theta)
#       8   return y_hat
#
# ValueError: dot: too many dimensions in result

# %%
theta
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-99-dde607ddc995> in <module>()
# ----> 1 theta
#
# NameError: name 'theta' is not defined

# %%
# Sua função deve retornar algo perto de 7 e 9
theta = gd(derivada_navera, media_erros_quadrados, X, y)
# Out:
# Iter 0; theta =
# [1.8973863  0.07713585]
# <NDArray 2 @cpu(0)>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-100-cfb2d23ba2d8> in <module>()
# ----> 1 theta = gd(derivada_navera, media_erros_quadrados, X, y)
#
# <ipython-input-90-d6c51819d4aa> in gd(d_fun, loss_fun, X, y, lambda_, tol, max_iter)
#      22     while True:
#      23         # Computar as derivadas
# ---> 24         grad = d_fun(X, theta, y)
#      25         # Atualizar
#      26         theta_novo = theta - lambda_ * grad
#
# <ipython-input-75-7a26e49df029> in derivada_navera(X, theta, y)
#       3     # pelo slide, temos : ((y - X @ 𝛉) * X.T).mean(axis=1)
#       4
# ----> 5   y_hat = np.dot(X, theta)
#       6   return ((y_hat - y) * X.T).mean(axis=1)
#       7
#
# ValueError: dot: too many dimensions in result

# %%
theta
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-101-dde607ddc995> in <module>()
# ----> 1 theta
#
# NameError: name 'theta' is not defined

# %% [markdown]
# 12. Altere a função de Gradiente Descendente para funcionar com minibatches. Em outras palavras, não compute o erro usando todos os dados de X. Use um `slice` de tamanho do minibatch. Uma ideia é seguir o pseudocódigo abaixo.
#
# ```python
# index = np.arange(len(X))
# while True:
#     minib = np.random.choice(index, minibatchsize) # aqui estou usando numpy para selection minibatch elementos
#     X_batch = X[minib]
# ```

# %%
# Exemplo abaixo
index = np.arange(len(X))
mb = np.random.choice(index, 50)
print(mb)
X[mb]
# Out:
# [129 674 718 750 978 520 110 362 451  23 983 419 280 975 358 667 977 314
#  855 204 927 986 844 793 925 420 915 289 861 779 334 397 181   0 702 246
#  145 984 572 402   0  86 603 656 670  26 424 391 814  13]
# [[ 1.          0.19974385]
#  [ 1.         -1.9411068 ]
#  [ 1.          0.9539557 ]
#  [ 1.         -0.948489  ]
#  [ 1.          1.915245  ]
#  [ 1.         -0.29915735]
#  [ 1.         -1.4029186 ]
#  [ 1.         -0.25764543]
#  [ 1.          0.60254997]
#  [ 1.         -1.7933522 ]
#  [ 1.          0.76667434]
#  [ 1.          0.14087798]
#  [ 1.          3.3397725 ]
#  [ 1.          0.22554377]
#  [ 1.         -1.6922293 ]
#  [ 1.         -0.26389077]
#  [ 1.          0.71739316]
#  [ 1.          0.03267157]
#  [ 1.          1.4719718 ]
#  [ 1.          0.98257786]
#  [ 1.         -1.711995  ]
#  [ 1.         -0.25520158]
#  [ 1.          0.5188873 ]
#  [ 1.          1.6633134 ]
#  [ 1.         -0.5735055 ]
#  [ 1.         -0.6291476 ]
#  [ 1.         -1.5017413 ]
#  [ 1.         -0.04136932]
#  [ 1.         -1.112209  ]
#  [ 1.          0.67873055]
#  [ 1.          2.2524652 ]
#  [ 1.          1.0827469 ]
#  [ 1.         -0.15245853]
#  [ 1.         -0.11660124]
#  [ 1.          1.272896  ]
#  [ 1.         -0.53421515]
#  [ 1.          1.1491399 ]
#  [ 1.         -0.64965504]
#  [ 1.          0.5869157 ]
#  [ 1.          0.0110882 ]
#  [ 1.         -0.11660124]
#  [ 1.         -0.02513701]
#  [ 1.         -1.8095816 ]
#  [ 1.         -1.7328364 ]
#  [ 1.         -0.22934346]
#  [ 1.         -1.2401689 ]
#  [ 1.         -1.1463968 ]
#  [ 1.         -1.4708049 ]
#  [ 1.          1.1798983 ]
#  [ 1.         -0.63423014]]
# <NDArray 50x2 @cpu(0)>

# %%
def minibatch_gd(d_fun, loss_fun, X, y, lambda_=0.01, tol=0.00001,
                 max_iter=10000, batch_size=10):
    '''
    Executa Gradiente Descendente. Aqui:
    
    Parâmetros
    ----------
    d_fun : é uma função de derivadas
    loss_fun : é uma função de perda
    X : é um vetor de fatores explanatórios.
        Copie seu código de intercepto da primeira aula.
        para adicionar o intercepto em X.
    y : é a resposta
    lambda : é a taxa de aprendizad
    tol : é a tolerância, define quando o algoritmo vai parar.
    max_ter : é a segunda forma de parada, mesmo sem convergir
              paramos depois de max_iter iterações.
    batch_size : tamanho do batch
    '''
    # implemente

    theta = nd.random.normal(shape=X.shape[1])
    print('Iter {}; theta = '.format(0), theta)
    old_err_sq = np.inf
    i = 0
    
    index = np.arange(len(X))
    while True:
        # pega o mini batch
        mb = np.random.choice(index, 50)
        Xmb = X[mb]
        ymb = y[mb]
        
        # Computar as derivadas
        grad = d_fun(Xmb, theta, ymb)
        # Atualizar
        theta_novo = theta - lambda_ * grad
        
        # Parar quando o erro convergir
        err_sq = loss_fun(Xmb, theta, ymb)
        if nd.abs(old_err_sq - err_sq) <= tol:
            break
        
        # Atualizar parâmetros e erro
        theta = theta_novo
        old_err_sq = err_sq
        
        # Informação de debug
        print('Iter {}; theta = '.format(i+1), theta)
        i += 1
        if i == max_iter:
            break
    return theta

# %%
# Sua função deve retornar algo perto de 7 e 9
minibatch_gd(derivada_mxnet, media_erros_quadrados, X, y)
# Out:
# Iter 0; theta =
# [0.40762472 0.8238177 ]
# <NDArray 2 @cpu(0)>
# ---------
# (2,)
# (50, 2)
# ---------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-105-6ae7bd9997f4> in <module>()
# ----> 1 minibatch_gd(derivada_mxnet, media_erros_quadrados, X, y)
#
# <ipython-input-104-9fdeaed4766d> in minibatch_gd(d_fun, loss_fun, X, y, lambda_, tol, max_iter, batch_size)
#      33
#      34         # Computar as derivadas
# ---> 35         grad = d_fun(Xmb, theta, ymb)
#      36         # Atualizar
#      37         theta_novo = theta - lambda_ * grad
#
# <ipython-input-69-fea7b8195668> in derivada_mxnet(X, theta, y)
#       2     theta.attach_grad()
#       3     with mx.autograd.record():
# ----> 4         e = media_erros_quadrados(X, theta, y)
#       5     e.backward()
#       6     return theta.grad
#
# <ipython-input-82-ae9b04fb586b> in media_erros_quadrados(X, theta, y)
#       1 def media_erros_quadrados(X, theta, y):
#       2
# ----> 3   y_hat = previsao(X,theta)
#       4   erro = y_hat - y
#       5   erro = np.power(erro,2)
#
# <ipython-input-97-8336f23034f8> in previsao(X, theta)
#       5   print(X.shape)
#       6   print('---------')
# ----> 7   y_hat = np.dot(X,theta)
#       8   return y_hat
#
# ValueError: dot: too many dimensions in result

# %% [markdown]
# ## Conjunto de Problemas 3: Logistic from Scratch

# %% [markdown]
# 12. Repita o mesmo processo para a Logística. Lembrando que a mesma tem a seguinte forma:
#
# $$f(x_i) = \frac{1}{1 + e^{-(1 + \theta_1 x_{i1} + \theta_2 x_{i2} + \cdots \theta_k x_{ik})}}$$
#
# Implemente a função logística.

# %%
def logistic(X, theta):
  ex = nd.dot(X, theta)
  res = 1.0/ (1 + np.exp(ex))
  return res

# %%
# testes, não apague!
X_teste = nd.random.normal(shape=(1000, 20000))
theta = nd.random.normal(shape=(20000))
y_hat_teste = logistic(X_teste, theta)
assert_equal(True, (y_hat_teste >= 0).asnumpy().all())
assert_equal(True, (y_hat_teste <= 1).asnumpy().all())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-107-45a0cccfe1e0> in <module>()
#       2 theta = nd.random.normal(shape=(20000))
#       3 y_hat_teste = logistic(X_teste, theta)
# ----> 4 assert_equal(True, (y_hat_teste >= 0).asnumpy().all())
#       5 assert_equal(True, (y_hat_teste <= 1).asnumpy().all())
#
# AttributeError: 'numpy.ndarray' object has no attribute 'asnumpy'

# %% [markdown]
# Usando a logística acima implemente uma função logistica_prever que retorna 0 ou 1. Use o limar dado na função.

# %%
def logistica_prever(X, theta, limiar=0.5):
  vero = logistic(X, theta)
  return vero> limiar

# %%
# testes, não apague!
X_teste = nd.random.normal(shape=(1000, 20000))
theta = nd.random.normal(shape=(20000))
y_hat_teste = logistica_prever(X_teste, theta)
for yi in y_hat_teste.asnumpy():
    assert(yi in {0, 1})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-109-2152319c3d6d> in <module>()
#       2 theta = nd.random.normal(shape=(20000))
#       3 y_hat_teste = logistica_prever(X_teste, theta)
# ----> 4 for yi in y_hat_teste.asnumpy():
#       5     assert(yi in {0, 1})
#
# AttributeError: 'numpy.ndarray' object has no attribute 'asnumpy'

# %% [markdown]
# Agora, implemente uma função de entropia cruzada da logística. A mesma, é proporcional ao inverso da verossimilhança. Para entender a derivação entre as duas faça uso dos [Slides](https://docs.google.com/presentation/d/1yGPETPe8o7PPOP6_CF38LHr3vpxgTEnF5LjP-1pkGIc/edit?usp=sharing).
#
# Sendo:
#
# $$ll(x_i,y_i~|~\theta) = y_i \log f(x_i\theta) + (1-y_i) \log (1-f(x_i\theta))$$
#
# A verossimilhança para uma observação. A entropia cruzada é a media da negação do termo para todos os exemplos:
#
# $$L(\theta) = -n^{-1}\sum_i \big((1-y_i)\log (1-f_{\theta}(x_i)) + y_i\log (f_{\theta}(x_i))\big)$$
#
# `dica: use nd.clip(logistic(X, theta), 0.001, 0.999)`. A função remove os 0 e 1s da logistic, evitando assim o valor log(0).

# %%
def cross_entropy_mean(X, theta, y):
    vero = logistic(X, theta)
    logit = nd.clip(vero, 0.00001, 0.99999)
    return -(y * nd.log(logit) + (1 - y) * nd.log(1 - logit)).mean()

# %%
# testes, não apague!
from sklearn import datasets
state = np.random.seed(20190187)

X, y = datasets.make_blobs(n_samples=200, n_features=2, centers=2)
X = nd.array(X)
y = nd.array(y)

for _ in range(100):
    theta = nd.random.normal(shape=(2, ))
    assert(cross_entropy_mean(X, theta, y) >= 0)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-111-194ba2150a88> in <module>()
#       8 for _ in range(100):
#       9     theta = nd.random.normal(shape=(2, ))
# ---> 10     assert(cross_entropy_mean(X, theta, y) >= 0)
#
# <ipython-input-110-e3ccb947dd69> in cross_entropy_mean(X, theta, y)
#       1 def cross_entropy_mean(X, theta, y):
#       2     vero = logistic(X, theta)
# ----> 3     logit = nd.clip(vero, 0.00001, 0.99999)
#       4     return -(y * nd.log(logit) + (1 - y) * nd.log(1 - logit)).mean()
#
# /usr/local/lib/python3.6/dist-packages/mxnet/ndarray/register.py in clip(data, a_min, a_max, out, name, **kwargs)
#
# AssertionError: Argument data must have NDArray type, but got [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00018674]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [7.4713125e-07]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [7.522883e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [5.273071e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [2.2363323e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00524762]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [1.2095739e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [5.639985e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00046187]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [3.4575946e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [1.3982413e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00096366]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00052997]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [8.410432e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [1.9839922e-07]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00092841]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [6.1481514e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [8.859441e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [2.3407288e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [6.385993e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [2.104789e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.0001903]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [2.8068433e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.0001706]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [5.4735447e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [1.0129595e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00131433]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [5.272124e-07]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00083315]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [1.0169783e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [7.8911144e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.0002134]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [9.078023e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.01650522]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00040836]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00079873]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [1.9360152e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [5.3850523e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [6.5208123e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [9.989771e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [2.73693e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [3.5325002e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00132209]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00038224]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [8.297875e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [2.054861e-07]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00096882]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00348763]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [8.937812e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [2.773439e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [4.5069173e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00155423]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00017661]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [8.763635e-07]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [2.6544101e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [1.0912648e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [1.2528861e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00108592]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00132386]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00027039]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [1.5525246e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [2.576236e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [4.4322052e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [3.8570404e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00105297]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [8.3049383e-07]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.02781242]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [3.2431267e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00073384]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [6.257735e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [9.937094e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [1.0270033e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.0275704]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [1.2839175e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [1.5637626e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00011678]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [4.8203574e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00779153]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [5.386297e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [2.107642e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00010847]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [6.5868056e-07]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00018881]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00067011]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00558112]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [7.848521e-07]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [7.39665e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.0012468]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00013921]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [1.2993379e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00025736]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00648281]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [3.2543112e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [3.300946e-07]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [1.8749998e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [2.9233432e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [2.8890188e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00010764]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [5.66652e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [2.1198752e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.0002334]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00025544]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00019619]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [6.00858e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [1.5801266e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00012966]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00022021]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00204335]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00085898]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [9.917741e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.5486843]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00016791]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00125623]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [8.6385975e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00030691]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00035709]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [1.6893504e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00234273]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.01037985]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [1.3786312e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [6.888672e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [2.3269484e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [4.879989e-07]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [1.0521993e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [2.9911387e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00247763]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [4.79961e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00020336]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [4.231981e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00030827]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00032774]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00038076]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [1.4806584e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00517483]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.001184]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00093415]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00012938]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [2.7261633e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00039478]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [1.2335998e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [1.2862877e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [2.935333e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [7.934948e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [1.9886579e-07]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [2.2199843e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.0001469]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00040715]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00013632]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00078446]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [7.256038e-07]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00043016]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [3.047394e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.01092238]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [2.4470924e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00161202]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [3.3191295e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [9.3459734e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [1.024724e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [2.2740799e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [1.2273512e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00200995]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [2.0487514e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [2.9311905e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.02091575]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [3.6377136e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00045783]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [1.8606409e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00103652]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.0002156]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [3.639101e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [1.8578643e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [3.7986763e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00018929]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00086867]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00036953]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.0138388]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [4.3245407e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00197464]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00902781]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00021988]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.01779254]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [8.754254e-07]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.0173454]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [9.864682e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [6.1084074e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [3.8899534e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00897491]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [5.4371576e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00659088]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [1.4189944e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.02548177]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [7.670604e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00014459]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [6.028898e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.02337181]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [2.1040914e-06]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00028189]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.0001811]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [3.7667218e-05]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00012035]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]

# %% [markdown]
# Agora implemente a derivada.

# %%
def derivada_mxnet_logit(X, theta, y):
    theta.attach_grad()
    with mx.autograd.record():
        e = cross_entropy_mean(X, theta, y)
    e.backward()
    return theta.grad

# %% [markdown]
# A partir daqui basta executar código.

# %%
plt.scatter(X.asnumpy()[:, 0], X.asnumpy()[:, 1], s=80, edgecolors='k')

# %% [markdown]
# 13. Assim como foi feito na primeira aula, abaixo testamos o seu código com um toy dataset.

# %%
# Use essa função antes de executar o GD
def add_intercept(X):
    Xn = nd.zeros(shape=(X.shape[0], X.shape[1] + 1))
    Xn[:, 0]  = 1
    Xn[:, 1:] = X
    return Xn

# %%
Xn = add_intercept(X)

theta = minibatch_gd(derivada_mxnet_logit, cross_entropy_mean, Xn, y)
# Out:
# Iter 0; theta =
# [ 1.344402    0.47553363 -0.5752262 ]
# <NDArray 3 @cpu(0)>
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-115-7bdbfbc9edd4> in <module>()
#       1 Xn = add_intercept(X)
#       2
# ----> 3 theta = minibatch_gd(derivada_mxnet_logit, cross_entropy_mean, Xn, y)
#
# <ipython-input-104-9fdeaed4766d> in minibatch_gd(d_fun, loss_fun, X, y, lambda_, tol, max_iter, batch_size)
#      33
#      34         # Computar as derivadas
# ---> 35         grad = d_fun(Xmb, theta, ymb)
#      36         # Atualizar
#      37         theta_novo = theta - lambda_ * grad
#
# <ipython-input-112-98142da03dcd> in derivada_mxnet_logit(X, theta, y)
#       2     theta.attach_grad()
#       3     with mx.autograd.record():
# ----> 4         e = cross_entropy_mean(X, theta, y)
#       5     e.backward()
#       6     return theta.grad
#
# <ipython-input-110-e3ccb947dd69> in cross_entropy_mean(X, theta, y)
#       1 def cross_entropy_mean(X, theta, y):
#       2     vero = logistic(X, theta)
# ----> 3     logit = nd.clip(vero, 0.00001, 0.99999)
#       4     return -(y * nd.log(logit) + (1 - y) * nd.log(1 - logit)).mean()
#
# /usr/local/lib/python3.6/dist-packages/mxnet/ndarray/register.py in clip(data, a_min, a_max, out, name, **kwargs)
#
# AssertionError: Argument data must have NDArray type, but got [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.99316484]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.9958295]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00577793]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.99350595]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.9972314]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.9834209]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.01723651]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.03743194]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.96657056]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.02550419]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.02314475]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.9946554]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.0200999]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.98563135]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00560317]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.01730485]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.01610616]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.9627181]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.99209034]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.98517376]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.9627181]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.01342544]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00638352]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.03011714]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.9969162]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00900682]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.01166463]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.0200999]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.9935535]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00721253]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.01537908]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.9881323]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.9674384]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.01755869]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.98681587]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.00632504]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.03743194]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.0057323]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.9973725]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.99836916]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.9800577]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.9876621]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.02030112]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.9832062]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.01039695]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.02109499]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.98458695]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.98756194]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.9881323]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  [[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[
# [0.02868523]
# <NDArray 1 @cpu(0)>]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]

# %%
y_p = logistica_prever(Xn, theta)
print((y == y_p).mean())
# Out:
# ---------------------------------------------------------------------------
# MXNetError                                Traceback (most recent call last)
# <ipython-input-116-835a617ed8ce> in <module>()
# ----> 1 y_p = logistica_prever(Xn, theta)
#       2 print((y == y_p).mean())
#
# <ipython-input-108-02d5f80074b7> in logistica_prever(X, theta, limiar)
#       1 def logistica_prever(X, theta, limiar=0.5):
# ----> 2   vero = logistic(X, theta)
#       3   return vero> limiar
#       4
#
# <ipython-input-106-c813bc22c31f> in logistic(X, theta)
#       1 def logistic(X, theta):
# ----> 2   ex = nd.dot(X, theta)
#       3   res = 1.0/ (1 + np.exp(ex))
#       4   return res
#
# /usr/local/lib/python3.6/dist-packages/mxnet/ndarray/register.py in dot(lhs, rhs, transpose_a, transpose_b, forward_stype, out, name, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/mxnet/_ctypes/ndarray.py in _imperative_invoke(handle, ndargs, keys, vals, out)
#      90         c_str_array(keys),
#      91         c_str_array([str(s) for s in vals]),
# ---> 92         ctypes.byref(out_stypes)))
#      93
#      94     if original_output is not None:
#
# /usr/local/lib/python3.6/dist-packages/mxnet/base.py in check_call(ret)
#     250     """
#     251     if ret != 0:
# --> 252         raise MXNetError(py_str(_LIB.MXGetLastError()))
#     253
#     254
#
# MXNetError: [00:33:11] src/operator/tensor/./dot-inl.h:1232: Check failed: L[!Ta].Size() == R[Tb].Size() (3 vs. 2) dot shape error: [200,3] X [2]
#
# Stack trace returned 10 entries:
# [bt] (0) /usr/local/lib/python3.6/dist-packages/mxnet/libmxnet.so(+0x4114ba) [0x7f8417bfd4ba]
# [bt] (1) /usr/local/lib/python3.6/dist-packages/mxnet/libmxnet.so(+0x411ad1) [0x7f8417bfdad1]
# [bt] (2) /usr/local/lib/python3.6/dist-packages/mxnet/libmxnet.so(+0xf43bf5) [0x7f841872fbf5]
# [bt] (3) /usr/local/lib/python3.6/dist-packages/mxnet/libmxnet.so(mxnet::imperative::SetShapeType(mxnet::Context const&, nnvm::NodeAttrs const&, std::vector<mxnet::NDArray*, std::allocator<mxnet::NDArray*> > const&, std::vector<mxnet::NDArray*, std::allocator<mxnet::NDArray*> > const&, mxnet::DispatchMode*)+0x94a) [0x7f841a55bbfa]
# [bt] (4) /usr/local/lib/python3.6/dist-packages/mxnet/libmxnet.so(mxnet::Imperative::Invoke(mxnet::Context const&, nnvm::NodeAttrs const&, std::vector<mxnet::NDArray*, std::allocator<mxnet::NDArray*> > const&, std::vector<mxnet::NDArray*, std::allocator<mxnet::NDArray*> > const&)+0x309) [0x7f841a565c89]
# [bt] (5) /usr/local/lib/python3.6/dist-packages/mxnet/libmxnet.so(+0x2c768c9) [0x7f841a4628c9]
# [bt] (6) /usr/local/lib/python3.6/dist-packages/mxnet/libmxnet.so(MXImperativeInvokeEx+0x6f) [0x7f841a462ebf]
# [bt] (7) /usr/lib/x86_64-linux-gnu/libffi.so.6(ffi_call_unix64+0x4c) [0x7f8466333dae]
# [bt] (8) /usr/lib/x86_64-linux-gnu/libffi.so.6(ffi_call+0x22f) [0x7f846633371f]
# [bt] (9) /usr/lib/python3.6/lib-dynload/_ctypes.cpython-36m-x86_64-linux-gnu.so(_ctypes_callproc+0x2b4) [0x7f8466547c64]
